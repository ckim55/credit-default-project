# %% [markdown]
# # 02 Modeling Results
#
# This notebook reads the generated metrics and figures after running `python -m src.train`. Use it to copy results into the final report.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import pandas as pd
from IPython.display import Image, display

# %%
metrics_path = ROOT / "results/metrics.csv"
metrics = pd.read_csv(metrics_path)
metrics

# %%
metrics.sort_values(["roc_auc", "pr_auc"], ascending=False)

# %%
thresholds = pd.read_csv(ROOT / "results/thresholds.csv")
thresholds.groupby("model").head(3)

# %%
for fig_name in ["roc_curve.png", "pr_curve.png", "confusion_matrix.png", "calibration_curve.png", "permutation_importance.png", "shap_summary.png"]:
    fig_path = ROOT / "figures" / fig_name
    if fig_path.exists():
        print(fig_name)
        display(Image(filename=str(fig_path)))

# %% [markdown]
# ## Report Writing Notes
#
# - Use the metric table for the Experiments & Results section.
# - Use ROC-AUC and PR-AUC to compare ranking quality.
# - Use the confusion matrix to discuss the false-positive/false-negative tradeoff.
# - Use calibration/Brier score to discuss whether the predicted probabilities are reliable.
# - Use permutation importance or SHAP to explain which features influence model decisions.
